# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_8760db995d144d1cab8bb99f8e30e4d7 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Rx3KcqqyVM0CvH2mcoC-oNhWl4AIgJNnLG4yj6qWbLXG',
    ibm_service_instance_id="iam-ServiceId-80092a7b-a6ab-4262-b7f0-11b4bbb372ac",
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_8760db995d144d1cab8bb99f8e30e4d7.get_object(Bucket='hdbc3bf4c3bf3454028bc34d6d765ab9a09',Key='HDB_cleaned.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#    ﻿Case                                               Data     Label
# 0     48  On 1 Aug, I was sick with stomachache, diahrre...    Waived
# 1     30  Dear Sir/Madam, With reference to the above me...  Rejected
# 2     16  JUMAAT IS LOADING FURNITURE FROM HIS AUNTIE UN...  Rejected
# 3     26  To The Officer In Charge, Dear Sir/Mdm, Do kin...  Rejected
# 4     10  Dear Sir/Madam, I am writing to appeal against...  Rejected

# %% [markdown]
# # Using NLTK for Word embeddings

# %%
# !pip install nltk
# Out:
# Requirement already satisfied (use --upgrade to upgrade): nltk in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): six in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from nltk)

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /gpfs/fs01/user/s9ac-
# [nltk_data]    |     efa7ddefc45728-3c618564d05f/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
import nltk, re, pprint
from nltk.corpus import names, reuters, webtext

# %%
df_data_2["Data"]=df_data_2["Data"].astype(str)

# %% [markdown]
# # Using Gensim model for Word Embedings

# %%
# !pip install gensim
# Out:
# Requirement already satisfied (use --upgrade to upgrade): gensim in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): smart-open>=1.2.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from gensim)
# Requirement already satisfied (use --upgrade to upgrade): scipy>=0.18.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from gensim)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5.0 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from gensim)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.11.3 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from gensim)
# Requirement already satisfied (use --upgrade to upgrade): boto>=2.32 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): boto3 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): requests in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): bz2file in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): botocore<1.6.0,>=1.5.0 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): s3transfer<0.2.0,>=0.1.10 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): jmespath<1.0.0,>=0.7.1 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil<3.0.0,>=2.1 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from botocore<1.6.0,>=1.5.0->boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied (use --upgrade to upgrade): docutils>=0.10 in /usr/local/src/conda3_runtime.v25/4.1.1/lib/python3.5/site-packages (from botocore<1.6.0,>=1.5.0->boto3->smart-open>=1.2.1->gensim)

# %%
from gensim.models import Word2Vec
from sklearn import preprocessing
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 

model = gensim.models.Word2Vec(df_data_2["Data"], min_count=1)

print(model)
# Out:
# 2018-01-11 02:31:15,552 : INFO : collecting all words and their counts
# 2018-01-11 02:31:15,554 : WARNING : Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# 2018-01-11 02:31:15,555 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-01-11 02:31:15,562 : INFO : collected 81 word types from a corpus of 53615 raw words and 83 sentences
# 2018-01-11 02:31:15,563 : INFO : Loading a fresh vocabulary
# 2018-01-11 02:31:15,564 : INFO : min_count=1 retains 81 unique words (100% of original 81, drops 0)
# 2018-01-11 02:31:15,565 : INFO : min_count=1 leaves 53615 word corpus (100% of original 53615, drops 0)
# 2018-01-11 02:31:15,566 : INFO : deleting the raw counts dictionary of 81 items
# 2018-01-11 02:31:15,568 : INFO : sample=0.001 downsamples 28 most-common words
# 2018-01-11 02:31:15,568 : INFO : downsampling leaves estimated 11551 word corpus (21.5% of prior 53615)
# 2018-01-11 02:31:15,569 : INFO : estimated required memory for 81 words and 100 dimensions: 105300 bytes
# 2018-01-11 02:31:15,570 : INFO : resetting layer weights
# 2018-01-11 02:31:15,573 : INFO : training model with 3 workers on 81 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-01-11 02:31:15,744 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-01-11 02:31:15,745 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-01-11 02:31:15,746 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-01-11 02:31:15,747 : INFO : training on 268075 raw words (57528 effective words) took 0.2s, 334852 effective words/s
# 2018-01-11 02:31:15,748 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Word2Vec(vocab=81, size=100, alpha=0.025)

# %%
from gensim import corpora

#df_data_2=pd.concat([df_data_2,tdf],axis=0)
documents = df_data_2["Data"]

# %%
print((documents))
# Out:
# 0     On 1 Aug, I was sick with stomachache, diahrre...
# 1     Dear Sir/Madam, With reference to the above me...
# 2     JUMAAT IS LOADING FURNITURE FROM HIS AUNTIE UN...
# 3     To The Officer In Charge, Dear Sir/Mdm, Do kin...
# 4     Dear Sir/Madam, I am writing to appeal against...
# 5     To officer incharge, on the date of offence, i...
# 6     Yes, I didn't notice that the carpark was rese...
# 7     Dear Sir/Mdm, I hope this email finds you well...
# 8     I drive my old sickly handicapped mother home ...
# 9     1) Good morning 2) I parked my car around 8pm ...
# 10    to officer in charge, im the driver of vec yp4...
# 11    I,Ting Kok Choon I/c no:S1171455B is the drive...
# 12    Hi Sir/Mdm, I am a season ticket holder in thi...
# 13    I have parked my vehicle at the opened space c...
# 14    To the Officer in charge, I am writing in this...
# 15    Im actually the season parking holder of carpa...
# 16    Hi first I have to admitted this is my mistake...
# 17    Dear Sir/ Mdm I was loading goods for my stall...
# 18    Dear Sir, I am writing in to seek your kind un...
# 19    Dear sir my car is going to sold this week aft...
# 20    Sorry for having parked at the season parking ...
# 21    Dear Sir/ Mdm I was loading goods for my stall...
# 22    The vehicle is delivering goods to support the...
# 23    Dear Sir/Mdm, I am writing to you to appeal on...
# 24    We wanted to load our luggages into the car. M...
# 25    I wash rushing to go to the toilet at my relat...
# 26     I am a grab driver and it was my first time i...
# 27    I am currently overseas, hence I did a tempora...
# 28    Dear Appeals officer, this appeal is for the w...
# 29    Good evening, My friend was having a party at ...
#                             ...
# 53    I, Goh Keng Wee, NRIC S7347724G, resident of B...
# 54    The carpark is full and overflowing with close...
# 55     I am a resident and I have season parking for...
# 56     Hi, I had diahorrea and there is no where for...
# 57    Dear Sir/Madam, I did not receive any summon n...
# 58     HOUGANG PARKVIEW Explanation: As you can see ...
# 59    Dear Sir/Madam, As it was a family bereavement...
# 60     I am writing to appeal against my notice of p...
# 61     Dear sir, Hereby would like to appeal for the...
# 62    New season parking ticket RFID tag was not dis...
# 63    I was sending my sick grandson back to his hom...
# 64    Dear Sir/Mdm, I'd like to re-appeal on the abo...
# 65    Dear Sir/Madame, Re: Notice Number J0271053K. ...
# 66     I drove home from Vivo City. Halfway through,...
# 67    Dear Sir/Madam, On 2/8/17 9.39pm, my car SLQ85...
# 68     Dear Sir/Mdm, I am writing to appeal against ...
# 69    Hi Sir/Madam I still have not recover from my ...
# 70     Dear sir/ma'am, I Muhammad Afiq of the above ...
# 71    On the above mentioned date and time, I've ord...
# 72    On the above mentioned date and time, i was de...
# 73    Dear Sir / Mdm, With regards on the day of off...
# 74    I am the resident of Block 139A where the car ...
# 75    We refer to your summon (Notice No. J0219132U)...
# 76    Hi Sir/Mdm, I writing in regards to my parking...
# 77    Dear In Charge, It has been a bad weather day ...
# 78     Hi HDB, I was with my grandma at the time to ...
# 79     Dear Sir/Mdm, I, Wong Meng Fai, NIRC : S76248...
# 80     Hi, Firstly, I appologise as it was Sunday an...
# 81     I'm appealing on behalf of my dad, he has bow...
# 82    Dear Sir/Madam, I was doing electrical trouble...
# Name: Data, dtype: object

# %%
from pprint import pprint  # pretty-printer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
wordnet_lemmatizer = WordNetLemmatizer()
porter_stemmer = PorterStemmer()
# remove common words and tokenize
stoplist_1 = (stopwords.words('english'))
#print ((stoplist))
##stoplist_2 = ['for',' a', 'of', 'the', 'and', 'to', 'in', 'any', 'with', 'then', 'acknowledged', 'thank','you', 'thanks', 'nric', 'name', 'postal', 'thanks', 'thanku','toa','payoh']
#stoplist=stoplist_1+stoplist_2
#print ((stoplist))
texts = [[word for word in document.lower().split() if word not in stoplist]
   for document in documents]

texts = [[token for token in text if token.isalpha()] for text in texts]

texts = [[wordnet_lemmatizer.lemmatize(token) for token in text] for text in texts]

texts = [[porter_stemmer.stem(token) for token in text] for text in texts]
   

# remove words that appear only once
#from collections import defaultdict

#frequency = defaultdict(int)
#for text in texts:
 #   for token in text:
  #      frequency[token] += 1
#texts = [[token for token in text if frequency[token] > 1]
#          for text in texts]

print ((texts))
# Out:
# [['sick', 'myalgia', 'fever', 'month', 'old', 'daughter', 'also', 'symptom', 'throughout', 'bare', 'fatigu', 'sent', 'babi', 'place', 'take', 'care', 'could', 'return', 'home', 'get', 'call', 'hope', 'could', 'come', 'could', 'drop', 'babi', 'without', 'need', 'find', 'park', 'lot', 'effort', 'requir', 'go', 'pick', 'white', 'lot', 'occupi', 'decid', 'park', 
', 'infront', 'canteen', 'limit', 'full', 'drive', 'look', 'park', 'realis', 'get', 'canteen', 'alot', 'heavi', 'vehicl', 'decid', 'temporarili', 'stop', 'car', 'park', 'lot', 'help', 'grandma', 'canteen', 'spaciou', 'wont', 'block', 'car', 'congesst', 'look', 'actual', 'park', 'return', 'car', 'alreadi', 'hope', 'could', 'review', 'appeal', 'give', 'chanc', 'never', 'got', 'park', 'ticket', 'place', 'never', 'park', 'car', 'lot', 'car', 'small', 'blind', 'spot', 'lorri', 'inconveni', 'lorri', 'might', 'caus', 'damag', 'time', 'hope', 'get', 'chanc', 'assur', 'happen'], ['notic', 'carpark', 'reserv', 'season', 'park', 'holder', 'pleas', 'waiv', 'reduc', 'amount', 'base', 'first', 'time'], ['dear', 'hope', 'email', 'find', 'write', 'receiv', 'composit', 'fine', 'illeg', 'park', 'blk', 'lor', 'toa ...

# %%
dictionary = corpora.Dictionary(texts)
dictionary.save('/tmp/deerwester.dict')  # store the dictionary, for future reference
print(dictionary)
print(dictionary.token2id)
# Out:
# 2018-01-11 04:05:10,830 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-01-11 04:05:10,840 : INFO : built Dictionary(1042 unique tokens: ['seek', 'level', 'pleas', 'rescind', 'household']...) from 83 documents (total 4002 corpus positions)
# 2018-01-11 04:05:10,841 : INFO : saving Dictionary object under /tmp/deerwester.dict, separately None
# TypeErrorTraceback (most recent call last)
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/gensim/utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     491         try:
# --> 492             _pickle.dump(self, fname_or_handle, protocol=pickle_protocol)
#     493             logger.info("saved %s object", self.__class__.__name__)
#
# TypeError: file must have a 'write' attribute
#
# During handling of the above exception, another exception occurred:
#
# PermissionErrorTraceback (most recent call last)
# <ipython-input-159-a22fc8a6202d> in <module>()
#       1 dictionary = corpora.Dictionary(texts)
# ----> 2 dictionary.save('/tmp/deerwester.dict')  # store the dictionary, for future reference
#       3 print(dictionary)
#       4 print(dictionary.token2id)
#
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/gensim/utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     493             logger.info("saved %s object", self.__class__.__name__)
#     494         except TypeError:  # `fname_or_handle` does not have write attribute
# --> 495             self._smart_save(fname_or_handle, separately, sep_limit, ignore, pickle_protocol=pickle_protocol)
#     496
#     497
#
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/gensim/utils.py in _smart_save(self, fname, separately, sep_limit, ignore, pickle_protocol)
#     370                                        compress, subname)
#     371         try:
# --> 372             pickle(self, fname, protocol=pickle_protocol)
#     373         finally:
#     374             # restore attribs handled specially
#
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/gensim/utils.py in pickle(obj, fname, protocol)
#     922
#     923     """
# --> 924     with smart_open(fname, 'wb') as fout:  # 'b' for binary, needed on Windows
#     925         _pickle.dump(obj, fout, protocol=protocol)
#     926
#
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     174             encoding = kw.pop('encoding', None)
#     175             errors = kw.pop('errors', DEFAULT_ERRORS)
# --> 176             return file_smart_open(parsed_uri.uri_path, mode, encoding=encoding, errors=errors)
#     177         elif parsed_uri.scheme in ("s3", "s3n", 's3u'):
#     178             return s3_open_uri(parsed_uri, mode, **kw)
#
# /gpfs/fs01/user/s9ac-efa7ddefc45728-3c618564d05f/.local/lib/python3.5/site-packages/smart_open/smart_open_lib.py in file_smart_open(fname, mode, encoding, errors)
#     669     except KeyError:
#     670         raw_mode = mode
# --> 671     raw_fobj = open(fname, raw_mode)
#     672     decompressed_fobj = compression_wrapper(raw_fobj, fname, raw_mode)
#     673     decoded_fobj = encoding_wrapper(decompressed_fobj, mode, encoding=encoding, errors=errors)
#
# PermissionError: [Errno 13] Permission denied: '/tmp/deerwester.dict'

# %%
dimensions = 100
model = gensim.models.Word2Vec(texts, min_count=1,size=dimensions)
# Out:
# 2018-01-11 04:05:11,933 : INFO : collecting all words and their counts
# 2018-01-11 04:05:11,935 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-01-11 04:05:11,937 : INFO : collected 1042 word types from a corpus of 4002 raw words and 83 sentences
# 2018-01-11 04:05:11,938 : INFO : Loading a fresh vocabulary
# 2018-01-11 04:05:11,942 : INFO : min_count=1 retains 1042 unique words (100% of original 1042, drops 0)
# 2018-01-11 04:05:11,943 : INFO : min_count=1 leaves 4002 word corpus (100% of original 4002, drops 0)
# 2018-01-11 04:05:11,947 : INFO : deleting the raw counts dictionary of 1042 items
# 2018-01-11 04:05:11,948 : INFO : sample=0.001 downsamples 74 most-common words
# 2018-01-11 04:05:11,949 : INFO : downsampling leaves estimated 3230 word corpus (80.7% of prior 4002)
# 2018-01-11 04:05:11,950 : INFO : estimated required memory for 1042 words and 100 dimensions: 1354600 bytes
# 2018-01-11 04:05:11,954 : INFO : resetting layer weights
# 2018-01-11 04:05:11,971 : INFO : training model with 3 workers on 1042 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-01-11 04:05:11,985 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-01-11 04:05:11,995 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-01-11 04:05:12,002 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-01-11 04:05:12,003 : INFO : training on 20010 raw words (16108 effective words) took 0.0s, 557503 effective words/s
# 2018-01-11 04:05:12,004 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
import numpy as np
result_array = np.empty((0, dimensions))

for text in texts:
    
        
    result_array = np.append(result_array, [model.wv[text].mean(0)], axis=0)

# %%
dt = pd.concat([pd.DataFrame(df_data_2["Label"]).reset_index(drop=True), pd.DataFrame(result_array).reset_index(drop=True)],  axis=1)
#dt

# %%
from sklearn.preprocessing import LabelEncoder
#dt["Class"] = dt["Class"].astype('category')
#dt["Class"] = dt["Class"].astype('category').cat.codes
le = LabelEncoder()
dt["Label"] = le.fit_transform(dt["Label"])
#dt = dt["Class"].apply(le.fit_transform())
#le.transform(dt["Class"])
print(dt)
# Out:
#     Label         0         1         2         3         4         5  \
# 0       1  0.007516 -0.003775  0.002161 -0.000349 -0.002043 -0.000223
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test=train_test_split(dt.drop("Label", axis = 1), dt.loc[:,"Label"],test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV

clf = RandomForestClassifier(n_estimators = 50, random_state = 0)
mean_score=[]
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(clf, dt.drop("Label", axis = 1), dt.loc[:,"Label"], cv=5)
mean_score.append(np.mean(scores))
print(mean_score)
# Out:
# [0.62573529411764706]

# %%
from sklearn.metrics.regression import mean_absolute_error, mean_squared_error

print('Training MAE: ', mean_absolute_error(y_train, downtime_model.predict(X_train)))
print('Training MSE: ', mean_squared_error(y_train, downtime_model.predict(X_train)))
print('Testing MAE: ', mean_absolute_error(y_test, downtime_model.predict(X_test)))
print('Testing MSE: ', mean_squared_error(y_test, downtime_model.predict(X_test)))
# Out:
# Training MAE:  0.0
# Training MSE:  0.0
# Testing MAE:  0.352941176471
# Testing MSE:  0.352941176471

# %% [markdown]
# #Test for new data
# df_data_2 = pd.read_csv(get_object_storage_file_with_credentials_3a0ba1e9220e4661b5f93b247f9c03d5('RioShift', 'Classification_update.csv'))
#
# #copy to new data frame
# ndt = df_data_2
#
# #copylast line into variable and update the text
# #Equipment Type (Cause Location)	Cause Location	Component	Effect	Cause	Classification	Explanation	Top Issue	Eff. Duration	Class
# new_data = pd.DataFrame([], columns=ndt.columns)
# #print(new_data)
# new_data.loc[0]=["Stacker","Pilbara Iron.Cape Lambert Port B.Stockyard.Stacking.ST12","stacker","Operational - Machine Relocation","Machine Setting Up","Operating Delay","Stockpile went full with 26 cars left changed to emergency stacking pattern after speaking with DS","","0:06:15","MEDIUM"]
# print(new_data)

# %%
from sklearn.svm import SVC
#from sklearn.grid_search import train_test_split

clf = SVC()
clf.fit(X_train,y_train)

from sklearn.cross_validation import cross_val_score
scores = cross_val_score(clf, dt.drop("Label", axis = 1), dt.loc[:,"Label"], cv=5)
scores
# Out:
# array([ 0.58823529,  0.58823529,  0.58823529,  0.5625    ,  0.5625    ])

# %%
import numpy as np
from collections import defaultdict
def predict_class(texts):
    dimensions = 100
    model = gensim.models.Word2Vec(texts, min_count=1,size=dimensions)
    result_arr = np.empty((0, dimensions))
    for text in texts:
        result_array = np.append(result_arr, [model.wv[text].mean(0)], axis=0)
    predict_dt = pd.DataFrame(result_array)
    return predict_dt

def clean_data(documents):
    stoplist_1=(stopwords.words('english'))    
    #print ((stoplist))
    stoplist_2 = ['for',' a', 'of', 'the', 'and', 'to', 'in', 'any', 'with', 'then', 'acknowledged', 'thank','you', 'thanks', 'nric', 'name', 'postal', 'thanks', 'thanku']
    stoplist=stoplist_1+stoplist_2
    #print ((stoplist))
    texts = [[word for word in document.lower().split() if word not in stoplist]
        for document in documents]

    texts = [[token for token in text if token.isalpha()] for text in texts]  
    texts = [[wordnet_lemmatizer.lemmatize(token) for token in text] for text in texts]

    return texts

# %%
t="I acknowledged that the Driver's information provided are true. Name: THAM YEW SOON Identification Type: NRIC No. NRIC No./Passport No.: S1191465I Postal Code: 560547 Blk/House No.: null Street Name: null Level and Unit No.: #04-2236 Building Name: null Explanation: New season parking ticket RFID tag was not display"
pre_dt = pd.DataFrame()
pre_dt = pre_dt.append({'Data': t}, ignore_index=True)
#pre_dt = pd.read_csv(text, sep=";")
pre_documents = pre_dt["Data"]
predict_list=clean_data(pre_documents)
#print ((predict_list))
predict_dt=predict_class(predict_list)
print ((predict_dt))
predicted = t_model.predict(predict_dt)
print(predicted)
# Out:
# 2018-01-11 03:27:23,276 : INFO : collecting all words and their counts
# 2018-01-11 03:27:23,277 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-01-11 03:27:23,278 : INFO : collected 18 word types from a corpus of 20 raw words and 1 sentences
# 2018-01-11 03:27:23,278 : INFO : Loading a fresh vocabulary
# 2018-01-11 03:27:23,279 : INFO : min_count=1 retains 18 unique words (100% of original 18, drops 0)
# 2018-01-11 03:27:23,280 : INFO : min_count=1 leaves 20 word corpus (100% of original 20, drops 0)
# 2018-01-11 03:27:23,281 : INFO : deleting the raw counts dictionary of 18 items
# 2018-01-11 03:27:23,282 : INFO : sample=0.001 downsamples 18 most-common words
# 2018-01-11 03:27:23,283 : INFO : downsampling leaves estimated 3 word corpus (15.0% of prior 20)
# 2018-01-11 03:27:23,284 : INFO : estimated required memory for 18 words and 100 dimensions: 23400 bytes
# 2018-01-11 03:27:23,285 : INFO : resetting layer weights
# 2018-01-11 03:27:23,286 : INFO : training model with 3 workers on 18 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-01-11 03:27:23,289 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-01-11 03:27:23,289 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-01-11 03:27:23,290 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-01-11 03:27:23,291 : INFO : training on 100 raw words (14 effective words) took 0.0s, 4164 effective words/s
# 2018-01-11 03:27:23,292 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
#          0         1         2         3         4         5         6   \
# 0  0.000725 -0.000777  0.001526 -0.001539  0.000596 -0.000334  0.000604
#
#          7        8         9     ...           90        91        92  \
# 0 -0.000037  0.00061 -0.000181    ...    -0.000975  0.001233  0.000626
#
#          93        94        95       96        97        98        99
# 0  0.000858 -0.001154  0.000807  0.00022  0.000225 -0.000351  0.000756
#
# [1 rows x 100 columns]
# [1]

# %%
from repository.mlrepositoryclient import MLRepositoryClient
from repository.mlrepositoryartifact import MLRepositoryArtifact
from repository.mlrepository import MetaProps, MetaNames

# %%
wml_credentials={
  "url": "https://ibm-watson-ml.mybluemix.net",
  "access_key": "aOvO24ysb6yucKxTq5JPExeGhdUHtus7ygRsL+AQnX+cP15qX5Esd1vHqfX212ApHxGxQ3pIogjgEOjN0TGDTcL0h32gVzPkwMbmHXNpi+FQYUqQmv73SQJrb1WXWeZv",
  "username": "193ce3c1-5084-4e01-8054-14b1b93226e9",
  "password": "c043d8eb-35ba-46be-a642-24db2a2418c9",
  "instance_id": "5c6f2813-2b5d-4532-ae5a-a47c756832d1"
}

# %%
ml_repository_client = MLRepositoryClient(wml_credentials['url'])
ml_repository_client.authorize(wml_credentials['username'], wml_credentials['password'])
props = MetaProps({MetaNames.AUTHOR_NAME:"Shilpa", MetaNames.AUTHOR_EMAIL:"jains@sg.ibm.com"})

# %%
model_artifact = MLRepositoryArtifact(final_model, name="HDB Analysis", meta_props=props)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-00837d372b32> in <module>()
# ----> 1 model_artifact = MLRepositoryArtifact(final_model, name="HDB Analysis", meta_props=props)
#
# NameError: name 'final_model' is not defined

# %%
saved_model = ml_repository_client.models.save(model_artifact)

# %%
saved_model.meta.available_props()
# Out:
# dict_keys(['lastUpdated', 'version', 'authorEmail', 'trainingDataRef', 'runtime', 'pipelineVersionHref', 'modelVersionHref', 'creationTime', 'modelType', 'authorName'])

# %%
print("modelType: " + saved_model.meta.prop("modelType"))
print("trainingDataSchema: " + str(saved_model.meta.prop("trainingDataSchema")))
print("creationTime: " + str(saved_model.meta.prop("creationTime")))
print("modelVersionHref: " + saved_model.meta.prop("modelVersionHref"))
# Out:
# modelType: scikit-model-0.17
# trainingDataSchema: None
# creationTime: 2018-01-08 08:22:36.214000+00:00
# modelVersionHref: https://ibm-watson-ml.mybluemix.net/v2/artifacts/models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84/versions/d9004119-a36f-4be6-b33d-93a494a7c406

# %%
loadedModelArtifact = ml_repository_client.models.get(saved_model.uid)
print(str(loadedModelArtifact.name))
# Out:
# HDB Analysis

# %%
import urllib3, requests, json

headers = urllib3.util.make_headers(basic_auth='{username}:{password}'.format(username=wml_credentials['username'], password=wml_credentials['password']))
url = '{}/v3/identity/token'.format(wml_credentials['url'])
response = requests.get(url, headers=headers)
mltoken = json.loads(response.text).get('token')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-9cdb480038d6> in <module>()
#       1 import urllib3, requests, json
#       2
# ----> 3 headers = urllib3.util.make_headers(basic_auth='{username}:{password}'.format(username=wml_credentials['username'], password=wml_credentials['password']))
#       4 url = '{}/v3/identity/token'.format(wml_credentials['url'])
#       5 response = requests.get(url, headers=headers)
#
# NameError: name 'wml_credentials' is not defined

# %%
print(mltoken)
# Out:
# eyJhbGciOiJSUzUxMiIsInR5cCI6IkpXVCJ9.....roAKaY6TDeiFrNRUoyEhynRlZZD8RgDb19w4-O0M9NvEHoz70Y84Ur-vCHKjApWQqXtO-9hxQZNUJM016xBGJwa6I7bottuQSdv69RjSfxh8irWvLr2uYLiZwj2GGatPyh7zIJqbnBrz3-r7o6aBUSlDSDjHnhZjBqH8QkYM4MLIFJuOzTqjGQmOymSa8k94cEMT03Gbv2iLQkxJpgiBpaSPNa247SefsDflrBd_8WGlgiUEKPrQuWv1lG8_SQwOiXY_ZeLys_yTsyzwe04g3t0pdM4VTzRHHvagSYU3EgAmZTHkXRJCn_HZ9gQMZ26Qh_QwDzwPIE8PmidVC8T30w

# %%
endpoint_instance = wml_credentials['url'] + "/v3/wml_instances/" + wml_credentials['instance_id']
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}

response_get_instance = requests.get(endpoint_instance, headers=header)

print(response_get_instance)
print(response_get_instance.text)
# Out:
# <Response [200]>
# {"metadata":{"guid":"5c6f2813-2b5d-4532-ae5a-a47c756832d1","url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1","created_at":"2017-08-28T15:32:47.560Z","modified_at":"2018-01-08T08:22:36.270Z"},"entity":{"source":"Bluemix","published_models":{"url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models"},"usage":{"expiration_date":"2018-02-01T00:00:00.000Z","computation_time":{"limit":18000,"current":0},"model_count":{"limit":200,"current":3},"prediction_count":{"limit":5000,"current":0},"deployment_count":{"limit":5,"current":3}},"plan_id":"3f6acf43-ede8-413a-ac69-f8af3bb0cbfe","status":"Active","organization_guid":"8c05fea4-7391-49dd-8fb4-92cd660b568d","region":"us-south","account":{"id":"500909797","name":"Abhishek Kaul's Account","type":"TRIAL"},"owner":{"ibm_id":"310000M4YR","email":"abhikaul@in.ibm.com","user_id":"dba4a4f3-2b6a-47dc-ad52-f77bcae1fc96","country_code":"IND","beta_user":true},"deployments":{"url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/deployments"},"space_guid":"0c53bd10-243e-4312-8dbb-1428890c1e61","plan":"lite"}}

# %%
endpoint_published_models = json.loads(response_get_instance.text).get('entity').get('published_models').get('url')

print(endpoint_published_models)
# Out:
# https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models

# %%
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}

response_get = requests.get(endpoint_published_models, headers=header)

print(response_get)
print(response_get.text)
# Out:
# <Response [200]>
# {"count":3,"resources":[{"metadata":{"guid":"943ca4fb-7ce3-4ec7-9460-aac921519dc7","url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/943ca4fb-7ce3-4ec7-9460-aac921519dc7","created_at":"2017-10-12T08:54:03.427Z","modified_at":"2017-10-12T09:08:28.058Z"},"entity":{"runtime_environment":"python-3.5","learning_configuration_url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/learning_configuration","author":{"name":"IBM","email":"ibm@ibm.com"},"name":"Satha Data Analysis","learning_iterations_url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/learning_iterations","feedback_url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/feedback","latest_version":{"url":"https://ibm-watson-ml.mybluemix.net/v3/ml_assets/models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/versions/12924d5b-dea3-4c63-867c-5342870cb8aa","guid":"12924d5b-dea3-4c63-867c-5342870cb8aa"},"model_type":"scikit-learn-0.17","deployments":{"count":2,"url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/deployments"},"deployed_version":{"url":"https://ibm-watson-ml.mybluemix.net/v3/ml_assets/models/943ca4fb-7ce3-4ec7-9460-aac921519dc7/versions/12924d5b-dea3-4c63-867c-5342870cb8aa","
# %%
payload_online = {"name": "HDB Analysis", "description": "My Deployment", "type": "online"}
response_online = requests.post(endpoint_deployments, json=payload_online, headers=header)

print(response_online)
print(response_online.text)
# Out:
# <Response [201]>
# {"metadata":{"guid":"e72d594a-3faa-4ac6-9bf1-2b8106694fca","url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84/deployments/e72d594a-3faa-4ac6-9bf1-2b8106694fca","created_at":"2018-01-08T08:23:17.842Z","modified_at":"2018-01-08T08:23:18.349Z"},"entity":{"runtime_environment":"python-3.5","name":"HDB Analysis","scoring_url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84/deployments/e72d594a-3faa-4ac6-9bf1-2b8106694fca/online","description":"My Deployment","published_model":{"author":{"name":"Shilpa","email":"jains@sg.ibm.com"},"name":"HDB Analysis","url":"https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84","guid":"fd5a8eb7-ab78-4f6a-a40d-b9894109ae84","created_at":"2018-01-08T08:23:17.810Z"},"model_type":"scikit-learn-0.17","status":"INITIALIZING","type":"online","deployed_version":{"url":"https://ibm-watson-ml.mybluemix.net/v3/ml_assets/models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84/versions/d9004119-a36f-4be6-b33d-93a494a7c406","guid":"d9004119-a36f-4be6-b33d-93a494a7c406"}}}

# %%
scoring_url = json.loads(response_online.text).get('entity').get('scoring_url')
print(scoring_url)
# Out:
# https://ibm-watson-ml.mybluemix.net/v3/wml_instances/5c6f2813-2b5d-4532-ae5a-a47c756832d1/published_models/fd5a8eb7-ab78-4f6a-a40d-b9894109ae84/deployments/e72d594a-3faa-4ac6-9bf1-2b8106694fca/online

# %%
payload_scoring = {'values': [predict_dt.iloc[-1].tolist()]}

print(payload_scoring)
# Out:
# {'values': [[0.00036226361407898366, -0.00038860979839228094, 0.00076291791629046202, -0.00076966371852904558, 0.00029791309498250484, -0.00016681353736203164, 0.00030215125298127532, -1.8606742742122151e-05, 0.00030522406450472772, -9.0253211965318769e-05, -0.00012957218859810382, -0.00030496827093884349, -0.0004367878136690706, 0.00022821912716608495, -7.2219468165712897e-06, -0.00055928749497979879, 0.00024720607325434685, -0.00048579665599390864, 0.00047484770766459405, -0.00042922893771901727, -0.00049340591067448258, -0.00034110283013433218, -0.00033479399280622602, 0.0002895733923651278, -0.00033850054023787379, -0.00045098137343302369, 0.00057706644292920828, 0.00022080985945649445, 0.00025344855384901166, 0.00026529142633080482, 0.00022875503054820001, -0.00069266150239855051, 0.00036567079951055348, -0.00025562156224623322, 0.00038114815833978355, 0.00054234603885561228, -0.00023980834521353245, 0.00012093786062905565, -2.573964957264252e-05, -0.00054074410581961274, -0.00048783287